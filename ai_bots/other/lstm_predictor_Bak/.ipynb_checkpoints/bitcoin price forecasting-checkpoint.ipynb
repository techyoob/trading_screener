# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
plt.style.use('ggplot')

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense, Dropout




import requests
import json

# %%
#df = pd.read_csv(r'D:\screener_project\ai_bots\lstm_predictor\BTC-USD.csv')
#df.tail()


tickerHistoryResponse = requests.get("https://financialmodelingprep.com/api/v3/"+"historical-price-full/"+"AAPL"+"?apikey="+"56e431b750c849dd5d42c5c0443186fc")
dailyHistory=tickerHistoryResponse.json()['historical'][::-1]
df = pd.DataFrame(dailyHistory)
df.tail()
# Out:
#             date        open        high         low       close    adjClose  \
# 1253  2021-03-30  120.110001  120.400002  118.860001  119.900002  119.900002
# 1254  2021-03-31  121.650002  123.519997  121.150002  122.150002  122.150002
# 1255  2021-04-01  123.660004  124.180000  122.489998  123.000000  123.000000
# 1256  2021-04-05  123.870003  126.160004  123.070000  125.900002  125.900002
# 1257  2021-04-06  126.500000  127.129997  125.650002  126.209999  126.209999
#
#            volume  unadjustedVolume  change  changePercent       vwap  \
# 1253   85671900.0        85671900.0   -0.21         -0.175  119.72000
# 1254  118323800.0       118323800.0    0.50          0.411  122.27333
# 1255   75089100.0        75089100.0   -0.66         -0.534  123.22333
# 1256   88395400.0        88395400.0    2.03          1.639  125.04334
# 1257   80171253.0        80171253.0   -0.29         -0.229  126.33000
#
#              label  changeOverTime
# 1253  March 30, 21        -0.00175
# 1254  March 31, 21         0.00411
# 1255  April 01, 21        -0.00534
# 1256  April 05, 21         0.01639
# 1257  April 06, 21        -0.00229

# %%
df = df.set_index("date")[['open']].tail(1000)
df = df.set_index(pd.to_datetime(df.index))

df.head()
print('done')
# Out:
# done

# %%
scaler = MinMaxScaler()
df = pd.DataFrame(scaler.fit_transform(df), columns =df.columns, index=df.index)
df.head()
# Out:
#                 open
# date
# 2017-04-17  0.000600
# 2017-04-18  0.000439
# 2017-04-19  0.001524
# 2017-04-20  0.000000
# 2017-04-21  0.002816

# %%
print('done')
df.plot(figsize=(14,8))
plt.title('aapl prices')
plt.ylabel('normalized prices')
plt.show()
# Out:
# done

# %%
def split_sequences(seq, n_steps_in, n_steps_out):
    X,y =[], []
    
    for i in range(len(seq)):
        end = i+n_steps_in
        out_end = end+ n_steps_out
        
        if out_end >len(seq):
            break
            
        seq_x, seq_y = seq[i:end], seq[end:out_end]
        
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)

# %%
def visualize_results(results):
    history = results.history
    plt.figure(figsize=(12,4))
    plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss','loss'])
    plt.title('Loss')
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.show()
    
    plt.figure(figsize=(12,4))
    plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_accuracy','accuracy'])
    plt.title('Accuracy')
    plt.xlabel('epochs')
    plt.ylabel('accuracy')
    plt.show()

# %%
n_per_in = 30
n_per_out = 1

n_features = 1

X,y = split_sequences(list(df.open), n_per_in,n_per_out)

print(X.shape)

X = X.reshape(X.shape[0],X.shape[1],n_features)

print(X.shape)
print(y.shape)
# Out:
# (961, 30)
# (961, 30, 1)
# (961, 10)

# %%
model = Sequential()
model.add(LSTM(40, activation='softsign', return_sequences=True, input_shape=(n_per_in,n_features)))
model.add(LSTM(15, activation='softsign', return_sequences=True))
model.add(LSTM(15, activation='softsign', return_sequences=True))
model.add(LSTM(15, activation='softsign', return_sequences=True))
model.add(LSTM(15, activation='softsign', return_sequences=True))
model.add(LSTM(15, activation='softsign'))
model.add(Dense(n_per_out))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 30, 40)            6720
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 30, 15)            3360
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 30, 15)            1860
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 30, 15)            1860
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 30, 15)            1860
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 15)                1860
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                160
# =================================================================
# Total params: 17,680
# Trainable params: 17,680
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mse', metrics=['accuracy'])

# %%
res = model.fit(X,y, epochs=120, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/120
# 27/27 [==============================] - 4s 39ms/step - loss: 0.0839 - accuracy: 0.1652 - val_loss: 0.4491 - val_accuracy: 0.0722
# Epoch 2/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0387 - accuracy: 0.0855 - val_loss: 0.2173 - val_accuracy: 0.0722
# Epoch 3/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0117 - accuracy: 0.1047 - val_loss: 0.0219 - val_accuracy: 0.0722
# Epoch 4/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0053 - accuracy: 0.0503 - val_loss: 0.0229 - val_accuracy: 0.0722
# Epoch 5/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0048 - accuracy: 0.0817 - val_loss: 0.0110 - val_accuracy: 0.0722
# Epoch 6/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0035 - accuracy: 0.0882 - val_loss: 0.0071 - val_accuracy: 0.0722
# Epoch 7/120
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0034 - accuracy: 0.0882 - val_loss: 0.0111 - val_accuracy: 0.0722
# Epoch 8/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0031 - accuracy: 0.0842 - val_loss: 0.0109 - val_accuracy: 0.0722
# Epoch 9/120
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0035 - accuracy: 0.1247 - val_loss: 0.0055 - val_accuracy: 0.0722
# Epoch 10/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0032 - accuracy: 0.1784 - val_loss: 0.0092 - val_accuracy: 0.0722
# Epoch 11/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0027 - accuracy: 0.1477 - val_loss: 0.0043 - val_accuracy: 0.0722
# Epoch 12/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0030 - accuracy: 0.1510 - val_loss: 0.0052 - val_accuracy: 0.0722
# Epoch 13/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0024 - accuracy: 0.1251 - val_loss: 0.0054 - val_accuracy: 0.0722
# Epoch 14/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 0.1421 - val_loss: 0.0058 - val_accuracy: 0.0722
# Epoch 15/120
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0019 - accuracy: 0.1664 - val_loss: 0.0064 - val_accuracy: 0.0619
# Epoch 16/120
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0023 - accuracy: 0.1531 - val_loss: 0.0066 - val_accuracy: 0.0722
# Epoch 17/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0019 - accuracy: 0.1383 - val_loss: 0.0067 - val_accuracy: 0.1959
# Epoch 18/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0020 - accuracy: 0.1921 - val_loss: 0.0076 - val_accuracy: 0.0722
# Epoch 19/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 0.1786 - val_loss: 0.0078 - val_accuracy: 0.2062
# Epoch 20/120
# 27/27 [==============================] - 0s 17ms/step - loss: 0.
# Epoch 115/120
# 27/27 [==============================] - 0s 19ms/step - loss: 7.0736e-04 - accuracy: 0.1666 - val_loss: 0.0175 - val_accuracy: 0.0722
# Epoch 116/120
# 27/27 [==============================] - 1s 19ms/step - loss: 6.4485e-04 - accuracy: 0.1934 - val_loss: 0.0146 - val_accuracy: 0.1134
# Epoch 117/120
# 27/27 [==============================] - 1s 19ms/step - loss: 6.4259e-04 - accuracy: 0.2056 - val_loss: 0.0131 - val_accuracy: 0.0722
# Epoch 118/120
# 27/27 [==============================] - 1s 19ms/step - loss: 6.5186e-04 - accuracy: 0.1738 - val_loss: 0.0146 - val_accuracy: 0.0619
# Epoch 119/120
# 27/27 [==============================] - 1s 19ms/step - loss: 6.4762e-04 - accuracy: 0.2025 - val_loss: 0.0130 - val_accuracy: 0.0619
# Epoch 120/120
# 27/27 [==============================] - 1s 19ms/step - loss: 6.2022e-04 - accuracy: 0.1750 - val_loss: 0.0142 - val_accuracy: 0.1031

# %%
visualize_results(res)

# %%
plt.figure(figsize=(12,4))

yhat = model.predict(X[-1].reshape(1,n_per_in,n_features)).tolist()[0]

yhat = scaler.inverse_transform(np.array(yhat).reshape(-1,1)).tolist()

actual = scaler.inverse_transform(y[-1].reshape(-1,1))

print("predicted ", yhat)
plt.plot(yhat, label='predicted')

print("actuals ", actual.tolist())
plt.plot(actual.tolist(), label='actual')

plt.title("Predicted vs Actual")
plt.ylabel('price')
plt.legend()
plt.show()
# Out:
# predicted  [[116.49223079924857], [116.55977471969307], [118.29938568983364], [117.66153328286087], [117.50497649325264], [118.07256747304285], [117.61033958704233], [118.52761752651907], [117.91793423927295], [118.6458064775262]]
# actuals  [[123.330002], [122.82], [119.54000099999999], [120.349998], [121.65000199999999], [120.110001], [121.65000199999999], [123.660004], [123.87000300000001], [126.49999999999999]]

# %%
yhat = model.predict(np.array(df.tail(n_per_in)).reshape(1,n_per_in,n_features)).tolist()[0]
yhat = scaler.inverse_transform(np.array(yhat).reshape(-1,1)).tolist()

preds = pd.DataFrame(yhat, index=pd.date_range(start=df.index[-1], periods=len(yhat),freq="D"), columns=df.columns)

print(preds)

periods = 10

actual = pd.DataFrame(scaler.inverse_transform(df[['open']].tail(periods)), index = df.open.tail(periods).index, columns = df.columns).append(preds.head(1))

plt.figure(figsize=(12,4))
plt.plot(actual, label='actuals')
plt.plot(preds, label='predictions')
plt.ylabel("price")
plt.ylabel('dates')
plt.title(f'forecasting the next {len(yhat)} days')
plt.legend()
plt.show()
# Out:
#                   open
# 2021-04-06  115.863706
# 2021-04-07  116.007275
# 2021-04-08  117.554440
# 2021-04-09  116.934165
# 2021-04-10  116.858404
# 2021-04-11  117.399381
# 2021-04-12  116.964412
# 2021-04-13  117.818723
# 2021-04-14  117.230934
# 2021-04-15  117.901823
